# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Extract

# %% [markdown]
# ### Datos

# %%
df = pd.read_csv("dataset_modelado_final.csv") 
df
# Out:
#      id_hogar  cve_municipio    municipio  pa_mediana_remesa  pa_media_remesa  \
# 0     H000001          14001       Acatic          419.80260       422.501261
# 1     H000002          14001       Acatic          462.37990       447.044609
# 2     H000003          14001       Acatic          396.26960       424.600829
# 3     H000004          14001       Acatic          425.30190       424.737900
# 4     H000005          14001       Acatic          603.86795       598.866825
# ...       ...            ...          ...                ...              ...
# 9995  H009996          14124  Zapotlanejo          586.66880       616.506278
# 9996  H009997          14124  Zapotlanejo          241.03500       265.017396
# 9997  H009998          14124  Zapotlanejo          240.54490       253.776383
# 9998  H009999          14124  Zapotlanejo          374.59730       375.997717
# 9999  H010000          14124  Zapotlanejo          488.73590       477.746673
#
#       pa_desv_remesa  pa_cv_remesa  pa_pendiente_24m  pa_pendiente_norm  \
# 0          98.712412      0.233638          2.990360           0.007123
# 1         112.415062      0.251463          0.544468           0.001178
# 2         111.381945      0.262322         -0.261379          -0.000660
# 3          85.778142      0.201955         -4.654266          -0.010943
# 4         162.981997      0.272151          5.823873           0.009644
# ...              ...           ...               ...                ...
# 9995      222.563443      0.361008          4.178937           0.007123
# 9996      104.022534      0.392512         -0.136696          -0.000567
# 9997       88.041580      0.346926         -0.141339          -0.000588
# 9998      120.059977      0.319310          6.212381           0.016584
# 9999      146.033880      0.305672         10.053339           0.020570
#
#       pa_n_meses_sin_envio  ...  pc_iim_dp2  pc_pct_viv_remesas  \
# 0                      1.0  ...    61.87355            9.698208
# 1                      1.0  ...    61.87355            9.698208
# 2                      0.0  ...    61.87355            9.698208
# 3                      1.0  ...    61.87355            9.698208
# 4                      0.0  ...    61.87355            9.698208
# ...                    ...  ...         ...                 ...
# 9995                   1.0  ...    61.80894           10.464466
# 9996                   1.0  ...    61.80894           10.464466
# 9997                   1.0  ...    61.80894           10.464466
# 9998                   1.0  ...    61.80894           10.464466
# 9999                   2.0  ...    61.80894           10.464466
#
#       pc_pct_viv_emigrantes  pc_imn_2020  pc_escolaridad_promedio_mun  \
# 0                   3.85099     0.890939                         7.29
# 1                   3.85099     0.890939                         7.29
# 2                   3.85099     0.890939                         7.29
# 3                   3.85099     0.890939                         7.29
# 4                   3.85099     0.890939                         7.29
# ...                     ...          ...                          ...
# 9995                2.93460     0.895359                         7.86
# 9996                2.93460     0.895359                         7.86
# 9997                2.93460     0.895359                         7.86
# 9998                2.93460     0.895359                         7.86
# 9999                2.93460     0.895359                         7.86
#
#       pc_pct_pob_ocupada_2sm  pc_score_regional  pc_sub_capacidad_pago  \
# 0                  66.098725           0.462267               0.355929
# 1                  66.098725           0.462267               0.355929
# 2                  66.098725           0.462267               0.355929
# 3                  66.098725           0.462267               0.355929
# 4                  66.098725           0.462267               0.355929
# ...                      ...                ...                    ...
# 9995               68.623897           0.496545               0.434251
# 9996               68.623897           0.496545               0.434251
# 9997               68.623897           0.496545               0.434251
# 9998               68.623897           0.496545               0.434251
# 9999               68.623897           0.496545               0.434251
#
#       pc_sub_intensidad_migratoria  default_12m
# 0                         0.666032            0
# 1                         0.666032            0
# 2                         0.666032            0
# 3                         0.666032            0
# 4                         0.666032            0
# ...                            ...          ...
# 9995                      0.657706            0
# 9996                      0.657706            0
# 9997                      0.657706            0
# 9998                      0.657706            0
# 9999                      0.657706            0
#
# [10000 rows x 31 columns]

# %% [markdown]
# ## Transform

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id_hogar                      10000 non-null  object
#  1   cve_municipio                 10000 non-null  int64
#  2   municipio                     10000 non-null  object
#  3   pa_mediana_remesa             10000 non-null  float64
#  4   pa_media_remesa               10000 non-null  float64
#  5   pa_desv_remesa                10000 non-null  float64
#  6   pa_cv_remesa                  10000 non-null  float64
#  7   pa_pendiente_24m              10000 non-null  float64
#  8   pa_pendiente_norm             10000 non-null  float64
#  9   pa_n_meses_sin_envio          10000 non-null  float64
#  10  pa_max_racha_sin_envio        10000 non-null  float64
#  11  pa_fuerza_estacional          10000 non-null  float64
#  12  pa_antiguedad_meses           10000 non-null  float64
#  13  pa_cuota_propuesta_mxn        10000 non-null  float64
#  14  pa_ratio_remesa_cuota         10000 non-null  float64
#  15  pb_edad                       10000 non-null  float64
#  16  pb_genero_F                   10000 non-null  float64
#  17  pb_n_dependientes             10000 non-null  float64
#  18  pb_escolaridad_ord            10000 non-null  float64
#  19  pb_vivienda_propia            10000 non-null  float64
#  20  pb_vivienda_rentada           10000 non-null  float64
#  21  pc_iim_dp2                    10000 non-null  float64
#  22  pc_pct_viv_remesas            10000 non-null  float64
#  23  pc_pct_viv_emigrantes         10000 non-null  float64
#  24  pc_imn_2020                   10000 non-null  float64
#  25  pc_escolaridad_promedio_mun   10000 non-null  float64
#  26  pc_pct_pob_ocupada_2sm        10000 non-null  float64
#  27  pc_score_regional             10000 non-null  float64
#  28  pc_sub_capacidad_pago         10000 non-null  float64
#  29  pc_sub_intensidad_migratoria  10000 non-null  float64
#  30  default_12m                   10000 non-null  int64
# dtypes: float64(27), int64(2), object(2)
# memory usage: 2.4+ MB

# %%
df.isnull().sum()
# Out:
# id_hogar                        0
# cve_municipio                   0
# municipio                       0
# pa_mediana_remesa               0
# pa_media_remesa                 0
# pa_desv_remesa                  0
# pa_cv_remesa                    0
# pa_pendiente_24m                0
# pa_pendiente_norm               0
# pa_n_meses_sin_envio            0
# pa_max_racha_sin_envio          0
# pa_fuerza_estacional            0
# pa_antiguedad_meses             0
# pa_cuota_propuesta_mxn          0
# pa_ratio_remesa_cuota           0
# pb_edad                         0
# pb_genero_F                     0
# pb_n_dependientes               0
# pb_escolaridad_ord              0
# pb_vivienda_propia              0
# pb_vivienda_rentada             0
# pc_iim_dp2                      0
# pc_pct_viv_remesas              0
# pc_pct_viv_emigrantes           0
# pc_imn_2020                     0
# pc_escolaridad_promedio_mun     0
# pc_pct_pob_ocupada_2sm          0
# pc_score_regional               0
# pc_sub_capacidad_pago           0
# pc_sub_intensidad_migratoria    0
# default_12m                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
len(df["municipio"].unique())
# Out:
# 124

# %% [markdown]
# There's 125 municipies in Jalisco , Mex.

# %% [markdown]
# ## Load

# %%
df = pd.read_csv("dataset_modelado_final.csv", index_col=0)
